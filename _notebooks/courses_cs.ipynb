# %% [markdown]
# # CS Courses
# - toc: true
# - comments: false
# - badges: false
# - comments: false
# - hide: true
# - search_exclude: true
# - permalink: /schedules/cs_course

# %% [markdown]
# <br>
#
# ### 1. 건너뛴 부분
# - 컴퓨터구조 : 어셈블러, 링커, 로더 자세한 설명 with DLL(다이나믹 링킹 라이브러리) → 5월안에 찾아서 공부하기
# <br><br>
#
# ### 2. 강의 자료
# - 논리회로 : [유튜브 뽕교수의전자공학][logical_circuit] 강의듣기
# - 임베디드시스템 : [최규상교수님(영남대)][embedded_system] 강의듣기
# - 마이크로프로세서 : [이인석교수님(한국기술교육대) 1][microprocessor1] + [이인석교수님(한국기술교육대) 2][microprocessor2]
# - 알고리즘 : [유튜브 jakelee][algorithm] + [남원홍교수님(건국대)][data_structure] + [조행래교수님(영남대)][file_processing] + 찾아서 공부
# - 컴퓨터구조 : [최규상교수님(영남대)][computer_architecture] + [네이버블로그 구믓][naver_computer_architecture]
# - 운영체제 : [양희재교수님(영남대)][operating_system] 강의듣기
# - 리눅스시스템 : [최태영교수님(금오공대)][linux_system] 강의듣기
# - 데이터베이스 : [한빛미디어 데이터베이스][database] 개론 책보기
# - 컴퓨터 네트워크 : [남윤석교수님(동국대)][data_communication] + [이석복교수님(한양대)][computer_network]
# - 소프트웨어공학 : [최은만교수님(동국대)][software_engineering]
# - 언어론 : [한빛미디어 프로그래밍 언어론][language_theory] 책보기
# - 컴파일러 : [강승식교수님(국민대)][compiler]
# - 이산수학 : [한빛미디어 컴퓨팅사고를 키우는 이산수학][discrete_math] 책보기
# <br><br>
#
# ### 3. 스케줄 및 진행현황
# - ~~논리회로 : 아날로그-디지털, 진수변환법, 보수표기법, 코드, 반도체, 다이오드, 트랜지스터, MOSFET, 불대수~~
# - ~~알고리즘 : 기초 알고리즘 (A La Russe, 유클리드호제법, 소수판별, 에라토스테네스의 체, 우선법),~~
# - ~~알고리즘 : 재귀호출 (피보나치, 하노이탑, 플러드필, 프랙탈트리, 파일찾기, 메모이제이션)~~
# - ~~알고리즘 : 정렬 알고리즘(버블,선택,삽입,쉘,퀵,합병,기수,계수,힙)~~
# - ~~알고리즘 : 검색알고리즘(순차검색, 이분검색, 내분검색)~~
# - ~~컴퓨터구조 : Performance of Computer~~
# - ~~운영체제 : 운영체제 개요, 프로세스 관리, CPU 스케줄링 알고리즘 (1) - 스케쥴링 척도, FCFS~~
# - ~~데이터베이스 : 데이터베이스 기본 개념~~
# - ~~컴퓨터 네트워크 : 데이터통신 서론, 네트워크 모델~~
# - ~~논리회로 : 민텀, 맥스텀, 표준형, 정형, Don't Care~~
# - ~~마이크로 프로세서 : 마이크로 컨트롤러~~
# - ~~알고리즘 : 자료구조의 분류, 단순구조, 문자열알고리즘~~
# - ~~컴퓨터구조 : Instructions: Language of the Computer 3차시 (1), (2)~~
# - ~~운영체제 : CPU 스케줄링 알고리즘 (2) - SJF, Priority, RR 스케쥴링~~
# - ~~데이터베이스 : 데이터베이스 관리 시스템 (DBMS)~~
# - ~~컴퓨터 네트워크 : 물리층 개요~~
# - ~~소프트웨어공학 : 소프트웨어공학 개요, 개발프로세스~~
# - ~~언어론 : 프로그래밍 언어론 개요~~
# - ~~논리회로 : K-Map, Q-M 방법~~
# - ~~마이크로 프로세서 : ATmega 128 특징~~
# - ~~알고리즘 : 리스트, 스택, 큐, 덱 + 응용 문제~~
# - ~~컴퓨터구조 : Instructions: Language of the Computer 4차시 (1), (2)~~
# - ~~운영체제 : CPU 스케줄링 알고리즘 (3) - 다중 큐 스케쥴링, 프로세스 생성과 소멸, 쓰레드~~
# - ~~데이터베이스 : 데이터베이스 시스템~~
# - ~~컴퓨터 네트워크 : 디지털 전송~~
# - ~~소프트웨어공학 : 애자일 프로세스~~
# - ~~언어론 : 프로그래밍 언어의 구문~~
# - ~~논리회로 : 2레벨구현, 해저드~~
# - ~~마이크로 프로세서 : 패턴을 이용한 LED 점등~~
# - 알고리즘 : 비선형구조 1 - 이진 트리, 2 - 힙, 검색 구조 - 맵, 집합, AVL트리, 2-3, 2-3-4, 레드블랙, 트라이, B, B\*, B+ 트리
# - 컴퓨터구조 : Instructions: Language of the Computer 5차시 (1), (2)
# - 운영체제 : 프로세스 동기화 - 프로세스 동기화의 중요성, 은행계좌 문제
# - 데이터베이스 : 관계 데이터 모델 (1)
# - 컴퓨터 네트워크 : 아날로그 전송
# - 소프트웨어공학 : 요구분석
# - 언어론 : 4장 변수
# - 이산수학 : 명제, 논리적 동치 (~~87P)
# - 논리회로 : 조합논리회로 1 (HA, FA, 2비트가산기)
# - 마이크로 프로세서 : 변수의 범위, 타이머/카운터, 오버플로 인터럽트
# - 알고리즘 : 비선형구조 3 - 그래프, 그래프 알고리즘 (기수검색, BFS, DFS, 최소 스패닝 트리(MST), 최소 공통조상 (LCA))
# - 컴퓨터구조 : Arichmetic for Computers 6차시 (1), (2)
# - 운영체제 : 임계구역 문제 - 임계구역문제, 동기화 도구
# - 데이터베이스 : 관계 데이터 모델 (2)
# - 컴퓨터 네트워크 : 대역 사용률
# - 소프트웨어공학 : 사용사례
# - 언어론 : 5장 : 바인딩
# - 이산수학 : 변수포함 명제, 추론 (~~101P)
# - 논리회로 : 조합논리회로 2 (인코더, 디코더, Enable, Active Low)
# - 마이크로 프로세서 : 채터링 방지 대책,
# - 알고리즘 : 그래프 알고리즘 (크루스칼, 프림, 다익스트라, 위상정렬, 플로이드 와샬, 이분매칭, 단절점과 단절성, 2-SAT)
# - 컴퓨터구조 :  The Processor 7차시 (1), (2)
# - 운영체제 : 세마포어 - 세마포를 사용한 프로세스 동기화
# - 데이터베이스 : 관계 데이터 연산 (1)
# - 컴퓨터 네트워크 : 전송매체
# - 소프트웨어공학 : UML 다이어그램 (1)
# - 언어론 : 6장 : 식
# - 이산수학 : 증명의 이해, 직접증명법, 간접증명법 (~~123P)
# - 논리회로 : 조합논리회로 3 (멀티플렉서, 디멀티플렉서)
# - 마이크로 프로세서 : 타이머/카운터
# - 알고리즘 : 그래프 응용 (강결합 요소, AOE 네트워크, 임계작업, 네트워크 플로우, 최소비용최대유량, 벨만-포드 알고리즘)
# - 컴퓨터구조 : The Processor 8차시 (1), (2)
# - 운영체제 : 생산자-소비자 문제 - 전통적 동기화 문제, 생산자-소비자 문제
# - 데이터베이스 : 관계 데이터 연산 (2)
# - 컴퓨터 네트워크 : 교환기
# - 소프트웨어공학 : UML 다이어그램 (2)
# - 언어론 : 7장 : 부프로그램
# - 이산수학 : 존재/반례증명법, 수학적 귀납법(137P)
# - 논리회로 : 조합논리회로 4 (3-State 버퍼, MSI설계, ROM, PLA, PAL)
# - 마이크로 프로세서 :  오버플로 인터럽트
# - 알고리즘 : 파일구조 개요 (레코드, 필드, 파일분류, 선정요소), 파일 처리 (파일 디렉토리 등, C유닉스, C스탠다드, Java 입출력)
# - 컴퓨터구조 : The Processor 9차시 (1), (2)
# - 운영체제 : 기타 전통적 동기화 문제 - 읽기-쓰기 문제, 식사하는 철학자 문제
# - 데이터베이스 : 데이터베이스 언어 SQL (1)
# - 컴퓨터 네트워크 : 데이터링크층 개요
# - 소프트웨어공학 : 설계원리
# - 언어론 : 8장 : 예외처리
# - 이산수학 : 집합의 개념, 집합의 종류, 집합연산 (159P)
# - 논리회로 : 순차논리회로 1 (SR래치, Gated래치, D래치)
# - 마이크로 프로세서 : 세그먼트
# - 알고리즘 : 순차파일 구조 (스트림파일, 필드, 레코드, 순차접근, 임의접근, 순차탐색, 헤더레코드, 입력순차파일, 키순차파일, 설계, 신마스터파일) 1
# - 컴퓨터구조 : Large and Fast: Exploiting Memory Hierarchy 10차시 (1), (2)
# - 운영체제 : 교착상태 - 교착상태 필요조건, 교착상태의 해결법
# - 데이터베이스 : 데이터베이스 언어 SQL (2)
# - 컴퓨터 네트워크 : 오류검츨 및 정정
# - 소프트웨어공학 : 아키텍처 설계
# - 언어론 : 9장 : 객체지향 프로그래밍
# - 이산수학 : 대수법칙, 집합의 분할 (~~175P)
# - 논리회로 : 순차논리회로 2 (플립플롭, JK플립플롭, JK래치)
# - 마이크로 프로세서 : 세그먼트 동적표시
# - 알고리즘 : 순차파일 구조 (스트림파일, 필드, 레코드, 순차접근, 임의접근, 순차탐색, 헤더레코드, 입력순차파일, 키순차파일, 설계, 신마스터파일) 2
# - 컴퓨터구조 : Large and Fast: Exploiting Memory Hierarchy 11차시 (1), (2)
# - 운영체제 : 모니터 - 프로세스 동기화의 다른 도구인 모니터 사용
# - 데이터베이스 : 데이터베이스 언어 SQL (3)
# - 컴퓨터 네트워크 : 데이터 링크 제어와 프로토콜
# - 소프트웨어공학 : UI 설계 및 실습
# - 언어론 : 10장 : 함수형 프로그래밍
# - 이산수학 : 행렬개념, 행렬 연산, 행렬 종류 (~~192P)
# - 논리회로 : 순차논리회로 3 (계수기, 카운터)
# - 마이크로 프로세서 : 세그먼트 동적 표시
# - 알고리즘 : 파일 정렬/합병 알고리즘 (내부정렬 , 외부정렬 (대체선택, 자연선택), 이진/밸런스이진/K way/폴리페이즈/캐스케이드 소트/머지, 2PMM, 호프만알고리즘) 1
# - 컴퓨터구조 : Large and Fast: Exploiting Memory Hierarchy 12차시 (1), (2)
# - 운영체제 : 정리와 복습 (1) - 프로세스 관리와 관련한 복습
# - 데이터베이스 : 데이터베이스 언어 SQL (4)
# - 컴퓨터 네트워크 : 매체접근 제어
# - 소프트웨어공학 : 디자인 패턴 (1)
# - 언어론 : 11장 : 논리형 프로그래밍
# - 이산수학 : 행렬식, 역행렬, 연립1차방정식 (~~212P)
# - 임베디드 시스템 : Embedded System & Real Time System
# - 마이크로 프로세서 : 동적표시 프로그램
# - 알고리즘 : 파일 정렬/합병 알고리즘 (내부정렬 , 외부정렬 (대체선택, 자연선택), 이진/밸런스이진/K way/폴리페이즈/캐스케이드 소트/머지, 2PMM, 호프만알고리즘) 2
# - 컴퓨터구조 : Storage and Other I/O Topics 13차시 (1), (2)
# - 운영체제 : 주기억장치 관리 개요 - 주기억장치 역사, 주소 개념, 메모리 절약 - 동적적재, 동적연결, 스와핑
# - 데이터베이스 : 데이터베이스 설계 (1)
# - 컴퓨터 네트워크 : 유선랜 (이더넷)
# - 소프트웨어공학 : 디자인 패턴 (2)
# - 컴파일러 : 컴파일러 개요
# - 이산수학 : 관계의 개념, 관계 표현, 관계 성질 (~~248P)
# - 임베디드 시스템 : Embedded System Board (Achro-5250)
# - 마이크로 프로세서 : 정적함수
# - 알고리즘 : 탐색구조 (인덱스, LRU, BST, AVL, 2-3, 2-3-4, 레드블랙, 트라이, B, B\*, B+트리 복습)
# - 컴퓨터구조 : Hard Disk Structure + Time Calculation
# - 운영체제 : 연속메모리할당 - 최초적합, 최적적합, 최악적합, 페이징 - 페이지 테이블, 주소변환
# - 데이터베이스 : 데이터베이스 설계 (2)
# - 컴퓨터 네트워크 : 다른 유선망 (점화막, 비동기 전달모드)
# - 소프트웨어공학 : 디자인 패턴 (3)
# - 컴파일러 : 언어와 문법
# - 이산수학 : 합성관계, 관계 폐포, 동치관계와 부분순서관계 (~~278P)
# - 임베디드 시스템 : Real Time Scheduling
# - 마이크로프로세서 : LCD 인터페이스
# - 알고리즘 : 인덱싱 알고리즘 (인덱스, 레코드연산, {컴포저,타이틀,세컨더리}인덱스, 인덱스 순차파일(VSAM/ISAM), 다중키 파일(역인덱스, 역파일, 다중리스트), 바인딩) 1
# - 컴퓨터구조 : Other Secondary Storages (Tape, Optical Disk, RAID, Flash Memory, SSD) (1)
# - 운영체제 : 세그멘테이션 - 세그멘트 테이블, 주소변환, 가상메모리 - 가상메모리 개요와 원리
# - 데이터베이스 : 정규화 (1)
# - 컴퓨터 네트워크 : 무선랜
# - 소프트웨어공학 : 디자인 패턴 (4)
# - 컴파일러 : 정규 언어
# - 이산수학 :  함수 개념, 함수 특성 (~~299P)
# - 임베디드 시스템 : Priority Inversion, Virtualization
# - 마이크로프로세서 : 문자표시 모듈 파일작성
# - 알고리즘 : 인덱싱 알고리즘 (인덱스, 레코드연산, {컴포저,타이틀,세컨더리}인덱스, 인덱스 순차파일(VSAM/ISAM), 다중키 파일(역인덱스, 역파일, 다중리스트), 바인딩) 2
# - 컴퓨터구조 : Other Secondary Storages (Tape, Optical Disk, RAID, Flash Memory, SSD) (2)
# - 운영체제 : 요구 페이징 - 요구페이징 개요, 페이지 부재, 페이지 교체 - 페이지 교체 필요성, 희생 페이지 설정 원칙
# - 데이터베이스 : 정규화 (2)
# - 컴퓨터 네트워크 : 연결 장치와 가상랜
# - 소프트웨어공학 : UML 코드매핑
# - 컴파일러 : 정규 표현
# - 이산수학 : 합성함수, 함수 종류 (~~315P)
# - 임베디드 시스템 : Linux Installation, Linux Commands, Vi Commands
# - 마이크로프로세서 : 16비트 타이머/카운터
# - 알고리즘 : n차원 공간파일구조 - (격자파일, k-d, k-d-b, 사분, R, R+, R\*트리)
# - 컴퓨터구조 : Other Secondary Storages (Tape, Optical Disk, RAID, Flash Memory, SSD) (3)
# - 운영체제 : 프레임 할당 - 프레임 할당, 정적/동적 할당, 쓰레싱, 페이지 크기
# - 데이터베이스 : 회복과 병행제어 (1)
# - 컴퓨터 네트워크 : 컴퓨터 네트워크의 기본
# - 소프트웨어공학 : 구현
# - 컴파일러 : 유한 오토마타
# - 이산수학 : 그래프 개념, 그래프 종류, 그래프 표현(~~355P)
# - 임베디드 시스템 : Embedded System Environment, Tool Chain
# - 마이크로프로세서 : 16비트 타이머/카운터 레지스터
# - 알고리즘 : 텍스트 파일구조 - (역리스트 파일, 시그니처 파일)
# - 컴퓨터구조 : Other Secondary Storages (Tape, Optical Disk, RAID, Flash Memory, SSD) (4)
# - 운영체제 : 페이지 교체 알고리즘 - FIFO, OPT, LRU, 전역/지역교체,
# - 데이터베이스 : 회복과 병행제어 (2)
# - 컴퓨터 네트워크 : 애플리케이션 계층
# - 소프트웨어공학 : 테스팅 (1)
# - 컴파일러 : 정규언어의 표현
# - 이산수학 : 오일러 해밀턴, 그래프 활용 (~~373P)
# - 임베디드 시스템 : Boot Loader, Boot Loader Installation
# - 마이크로프로세서 : 16비트 타이머/카운터 실습
# - 알고리즘 : 해싱 알고리즘 (직접파일, 상대파일, 해싱(중간제곱, 중첩), 콜리전(선형탑색, 독립오버플로,이중해싱, 동거자체인, 버킷주소, 테이블해싱), 확장성직접파일(가상해싱), 동적해싱, 확장성해싱, 선형해싱), 해시테이블 1
# - 운영체제 : 파일 할당 - 디스크 구조, 파일 위한 디스크 블록 할당, 연속할당, 연결할당의 장단점
# - 데이터베이스 : 보안과 권한관리 (3)
# - 컴퓨터 네트워크 : 유선랜 (4), 무선랜 (1)
# - 소프트웨어공학 : 테스팅 (2)
# - 컴파일러 : LEX
# - 이산수학 : 트리 개념, 이진트리 (~~400P)
# - 임베디드 시스템 : Linux Kernel, Linux File System Installation
# - 마이크로프로세서 : 타이머/카운터 주파수 측정
# - 알고리즘 : 해싱 알고리즘 (직접파일, 상대파일, 해싱(중간제곱, 중첩), 콜리전(선형탑색, 독립오버플로,이중해싱, 동거자체인, 버킷주소, 테이블해싱), 확장성직접파일(가상해싱), 동적해싱, 확장성해싱, 선형해싱), 해시테이블 2
# - 운영체제 : 디스크 스케쥴링 - 색인할당, 디스크 탐색시간, FCFS, SSTF, SCAN 알고리즘 및 변종
# - 데이터베이스 : 보안과 권한관리 (4)
# - 컴퓨터 네트워크 : 애플리케이션 계층
# - 소프트웨어공학 : 유지보수
# - 컴파일러 : 문맥자유문법
# - 이산수학 : 트리의 활용(~~432P)
# - 임베디드 시스템 : Linux File System, Linux Kernel Configuration
# - 마이크로프로세서 : RC서보모터 구동
# - 알고리즘 : 그리디 기법 (압축 알고리즘 (권오흠)), 다이나믹 프로그래밍 (Knapsack, 외판원순회 문제, 설탕배달)
# - 운영체제 : 블로킹, 스풀링, 버퍼링- 디스크버퍼, 페이지캐시, 단순버퍼, 예상버퍼, 디블로킹, 이중버퍼, 버퍼링풀링, 버퍼링계산 (1)
# - 데이터베이스 : 데이터베이스 응용기술 (1)
# - 컴퓨터 네트워크 : 전송층 개념
# - 소프트웨어공학 : 프로젝트 관리 (1)
# - 컴파일러 : 문법의 유형
# - 이산수학 : 불대수 개념, 표현, 논리게이트 (~~493P)
# - 임베디드 시스템 : System Call, Adding a New System Call
# - 마이크로프로세서 : 아날로그 디지털 변환기
# - 알고리즘 : 백트래킹 (N-Queen 문제, Bounded Traveling Salesman 문제, 분할정복 (Strassen의 행렬곱셈, Closeset Pair)
# - 운영체제 : 블로킹, 스풀링, 버퍼링- 디스크버퍼, 페이지캐시, 단순버퍼, 예상버퍼, 디블로킹, 이중버퍼, 버퍼링풀링, 버퍼링계산 (2)
# - 데이터베이스 : 데이터베이스 응용기술 (2)
# - 컴퓨터 네트워크 : Congestion Control
# - 소프트웨어공학 : 프로젝트 관리 (2)
# - 컴파일러 : 구문분석 (1)
# - 이산수학 : 합법칙, 곱법칙, 순열, 조합 (~~523P)
# - 임베디드 시스템 : Module Programming, Proc File System
# - 마이크로프로세서 : 싱글엔드 입력과 차등입력
# - 알고리즘 : 완전 탐색 알고리즘 (비트마스크, 순열), 기하 알고리즘 (CCW, Convex Hull, Line Sweeping)
# - 운영체제 : 블로킹, 스풀링, 버퍼링- 디스크버퍼, 페이지캐시, 단순버퍼, 예상버퍼, 디블로킹, 이중버퍼, 버퍼링풀링, 버퍼링계산 (3)
# - 데이터베이스 : 데이터 과학과 빅데이터 (1)
# - 컴퓨터 네트워크 : 네트워크층 개요, IP프로토콜 (1)
# - 소프트웨어공학 : 품질관리
# - 컴파일러 : 구문분석 (2)
# - 이산수학 : 확률, 확률분포 (~~543P)
# - 임베디드 시스템 : Adding a New Entry into Proc File System, Device Driver
# - 마이크로프로세서 : USART 1
# - 알고리즘 : 서로소 집합 (Disjoint), 유니온 파인드 (Union Fine), 이항계수, 카탈란 수, 오일러 피함수
# - 리눅스 시스템 : 시스템 관리
# - 데이터베이스 : 데이터 과학과 빅데이터 (2)
# - 컴퓨터 네트워크 : 라우팅 프로토콜 (1), (2)
# - 소프트웨어공학 : 추가차시
# - 컴파일러 : 파서
# - 이산수학 :  알고리즘 개념, 알고리즘 효율성, 다양한 알고리즘 (565P)
# - 임베디드 시스템 : Device Driver Implementation, Achro-5250's Device Driver (1)
# - 마이크로프로세서 : USART 2
# - 알고리즘 : 다항식 (다항식 개요, 라그랑지보간법), 행렬 (DenseMatrix, 가우스-조르단 소거법, SparseMatrix), 방정식 (이분법, Regular Falsi법, 시컨트법, 뉴턴법)
# - 리눅스 시스템 : 부팅
# - 컴퓨터 네트워크 : 라우팅 프로토콜 (3), (4)
# - 소프트웨어공학 : 추가차시
# - 임베디드 시스템 : Achro-5250's Device Driver (2), Anchro-5250 Display Control
# - 마이크로프로세서 : 스텝모터 구동
# - 알고리즘 : 미적분 1 (수치미분, 수치적분 - 사각형법, 사다리꼴법), 미적분 2 (수치적분 - 심슨법, AdaptiveQuadrature, 몬테카를로법)
# - 리눅스 시스템 : 파일입출력 (1), (2)
# - 컴퓨터 네트워크 : 라우팅 프로토콜 (5), 유선랜(1)
# - 알고리즘 : 회귀 (회귀 개요, 선형회귀, 회귀분석 일반화)
# - 리눅스 시스템 : 파일과 디렉토리 (1), (2)
# - 컴퓨터 네트워크 : 유선랜 (2), (3)
# - 알고리즘 : 스플리안 (허밋 스플리안, 베지어 스플리안, 카스텔죠 알고리즘, B스플라인)
# - 리눅스 시스템 : 프로세스 (1), (2)
# - 컴퓨터 네트워크 : 멀티미디어 네트워크
# - 리눅스 시스템 : 소켓프로그래밍 (1), (2)
# - 컴퓨터 네트워크 : 네트워크 보안 (1), (2)
# - 리눅스 시스템 : Signal, IPC(1), (2)
# - 리눅스 시스템 : 고급 I/O
#
#
# [logical_circuit]:https://www.youtube.com/watch?v=23kEL4QLhuM&list=PL4mqT4nB0TyAV8zfXyyiW--ZZx2pN8Sto
# [embedded_system]:http://www.kocw.net/home/search/kemView.do?kemId=1174876
# [microprocessor1]:http://www.kocw.net/home/search/kemView.do?kemId=153708
# [microprocessor2]:http://www.kocw.net/home/search/kemView.do?kemId=168947
# [algorithm]:https://www.youtube.com/watch?v=mzM3S5FtKuw&list=PLl5LpJCoD2mCIRn0Fkt8z07EK320ZmHgY
# [data_structure]:http://www.kocw.net/home/search/kemView.do?kemId=1190355
# [file_processing]:http://www.kocw.net/home/m/search/kemView.do?kemId=1014820
# [computer_architecture]:http://www.kocw.net/home/search/kemView.do?kemId=1125218
# [naver_computer_architecture]:https://m.blog.naver.com/PostList.nhn?blogId=mayooyos&categoryNo=26&listStyle=style1
# [operating_system]:http://www.kocw.net/home/search/kemView.do?kemId=978503
# [linux_system]:http://www.kocw.net/home/search/kemView.do?kemId=1266434
# [data_communication]:http://www.kocw.net/home/search/kemView.do?kemId=1210517
# [computer_network]:http://www.kocw.net/home/search/kemView.do?kemId=1169634&ar=relateCourse
# [software_engineering]:http://www.kocw.net/home/search/kemView.do?kemId=1300178
# [compiler]:http://ocw.kookmin.ac.kr/?course=17980
# [database]:http://www.yes24.com/Product/Goods/9194489
# [language_theory]:https://www.hanbit.co.kr/store/books/look.php?p_code=B2476698303
# [discrete_math]:http://www.yes24.com/Product/Goods/35196368
