# %% [markdown]
# # 01. 미적분 기초 (1)
# > 머신러닝에 반드시 필요한 미적분의 기초 이론을 배웁니다.
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [Day 2]
# - permalink: /calculus_theory
# - exec: colab

# %% [markdown]
# 미적분은 우리가 머신러닝을 하면서 최적해를 구하기 위해 사용하는 일종의 Tool입니다. 이미 미적분에 대한 내용은 배우셨겠지만, 여기에서 다시한번 개념을 짚고 넘어가도록 하겠습니다.

# %% [markdown]
# <br><br>
#
# ### 1. 원의 넓이를 구해보자.
# 원의 넓이는 잘 아시다시피 $\pi r^2$입니다. 그런데 왜 $\pi r^2$일까요? 한번 반지름 3인 원의 넓이를 직접 떠올려봅시다. 원의 넓이를 곧바로 구할 수는 없기 때문에 한번 쪼개서 구해보도록 합시다.
# <br><br>
#
#
# #### 1.1. 어떻게 잘라낼까?
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/22.jpg?raw=true)
#
# 다양한 방법으로 원을 잘라낼 수 있습니다. 그러나 우리는 결론적으로 가장 오른쪽과 같이 잘라내는 방법을 사용할 것입니다. 저렇게 자르면 **각 잘라진 면이 하나의 원띠처럼 나올 것이기 때문이고, 그 원띠를 잘라내면 곡선이 없어서 계산하기 수월**할 것입니다. 만약 첫번째나 두번째, 네번째 처럼 자른다면 끝 부분에 곡선부분이 있어서 계산하기 어려워 보입니다.
# <br><br>
#
# #### 1.2. 그렇다면 각각의 링의 넓이는 어떻게 구할까?
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/23.gif?raw=true)
#
# 우리가 위와 같은 각각의 링의 넓이를 구하고, 이 넓이를 모두 더하면 최종적으로 원의 넓이를 알 수 있게 됩니다. 링 하나를 쭉 펴면 평행사변형이 된다만, **그냥 윗변과 아랫변이 같다고 놓고** 계산해봅시다. 이는 그냥 간단하게 생각하기 위함입니다. 어차피 정확한 값이 아니라 근사 값을 구할 것이기 때문입니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/24.gif?raw=true)
#
# 하나의 띠의 가로 길이는 $2 \pi r$입니다. 그것은 $\pi$의 정의입니다. 그렇다면 세로 길이는 무엇일까요? 우리는 여기에서 미적분학의 표기인 $dr$이라는 표현을 사용해봅시다. $dr$은 0.1과 같은 작은 숫자입니다.
# <br><br>
#
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/25.gif?raw=true)
#
# 따라서 사각형이라고 가정한 원띠의 넓이는 가로 x 세로인 $2 \pi r \times dr$이 됩니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/26.gif?raw=true)
#
# 아까도 말했지만 이 넓이는 근차시입니다. 따라서 완벽하지 않습니다. **그러나 $dr$의 크기를 줄이면 줄일 수록 윗변과 아랫변의 길이는 비슷**해지기 때문에 점점 정확한 값이 됩니다. 자, 이 사각형 띠들의 넓이를 모두 더하면 곧 원의 넓이가 됩니다. 그렇다면 이 사각형 띠들의 넓이를 모두 어떻게 더할까요?
# <br><br>
#
# #### 1.3. 어떻게 작은 사각형 띠들을 더할까
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/27.gif?raw=true)
#
# 위와 같은 수직선을 생각할 수 있을 것입니다. 가장 작은 띠의 반지름은 0에 가까울 것이고, 가장 큰 띠의 반지름은 3에 가까울 것입니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/28.gif?raw=true)
#
# 그리고 수직선을 잘게 쪼개 하나의 단위를 $dr$이라고 생각하고 거기에 사각형 띠를 하나 놓을 수 있습니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/29.gif?raw=true)
#
# 이렇게 모든 사각형 띠를 수직선 위에 올려놓으면 위와 같은 형태를 생각할 수 있습니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/30.gif?raw=true)
#
# 각 사각형 띠는 밑변이 $dr$ 높이가 $2 \pi r$이 되고, 이렇게 쌓은 사각형 띠들의  넓이는 위에서 말한 것 처럼 $2 \pi r \times dr$이 됩니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/31.gif?raw=true)
#
# 가장 큰 사각형 띠는 반지름이 3정도 되기 때문에 $2 \pi r \times dr$은 대략 18정도 됩니다. 화면을 넘어가기 때문에 y축의 범위를 변경시켜서 보기 편하게 해봅시다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/32.gif?raw=true)
#
# 각 사각형 띠들의 높이를 하나의 직선으로 표시할 수 있고 그 직선은 $y = 2\pi r$이 됩니다. 따라서 삼각형의 넓이를 구하려면 $2 \pi r \times 3$을하면 마치 전체 넓이를 구할 수 있을 것 처럼 보입니다. 그러나 아직 작은 오차들이 존재합니다.
# <br><br>
#
# #### 1.4. 어떻게 오차를 줄일 수 있을까?
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/33.gif?raw=true)
#
# 이전에 말했듯이 $dr$이 작아지면 작아질 수록 이 오차는 점점 작아지게 됩니다. 때문에 $dr$을 0은 아니지만 거의 0에 가깝게 줄여봅시다.
# <br><br>
#
#
# #### 1.5. 원의 넓이 계산
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/34.gif?raw=true)
#
# 삼각형의 넓이는 $\frac{1}{2}$ x 밑변 x 높이로 구할 수 있습니다. 여기에서 밑변은 3이고 높이는 $2 \pi \times 3$입니다.
# <br><br>
#
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/35.gif?raw=true)
#
# 이것을 일반화 시키면 바로 $\pi r^2$이 됩니다. 간단하죠? 적분공식 없이 정적분을 성공적으로 수행했습니다. 이렇게 미적분이라는 것은 어떤 어려운 문제를 작게 나누고 합쳐서 푸는데에 있어서 굉장히 좋은 생각의 프레임워크입니다. <br><br>
#
# 그러나 사실 머신러닝에서는 적분은 잘 사용하지 않고, 대부분 미분을 이용하여 문제를 해결하는 경우가 많습니다. 때문에, 저는 미분 공식을 유도하기 위해 먼저 적분을 여러분에게 소개해드린 것입니다. 그러면 미분은 뭘까요? <br><br>

# %% [markdown]
# <br>
#
# ### 2. 그러면 미분은 뭘까요?
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/36.gif?raw=true)
#
# 이번엔 원이 아니라 $y = x^2$의 아랫부분 넓이를 생각해봅시다. 이 넓이를 구하는 것은 곧바로 생각하기는 조금 어려워보입니다. 그러면 이번에도 문제를 잘게 쪼개서 생각해보도록 합시다.
# <br><br>
#
# #### 2.1. 넓이를 의미하는 함수 A(x)
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/37.gif?raw=true)
#
# 새로운 함수 하나를 정의합니다. $A(x)$는 $0$부터 $x$까지의 넓이를 의미한다고 정의하겠습니다.  만약 $A(3)$이라고 하면 $0$부터 $3$까지의 넓이입니다. (여기에서 $A$는 $Area$입니다.)
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/38.gif?raw=true)
#
# $0$부터 $x$까지의 넓이를 한번에 구하기는 너무 어려우니, 원의 넓이를 구할때처럼 쪼개서 생각할 것입니다. 작은 구간인 $dx$를 정의하고, $x$까지의 넓이를 $dA$라고 하겠습니다. 이 때, $dA$는 difference of Area의 약자입니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/39.gif?raw=true)
#
# 그렇다면 윗부분의 작은 녹색 삼각형 오차는 무시하고, 길쭉한 노란색 사각형의 넓이만 구해봅시다. 노란색 사각형만 생각하는 이유는 원의 넓이를 구했을 때처럼 근사해서 편하게 구하기 위함입니다. 가로의 길이는 $dx$이고, 세로의 길이는 $x^2$입니다. 따라서 $dA \approx x^2 dx$가 됩니다.
# <br><br>
#
# #### 2.2. 밑변(dx)으로 나누기
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/40.gif?raw=true)
#
# 그렇다면 양변을 $dx$로 나눠서 위처럼 $\frac{dA}{dx} \approx x^2$라고 생각해도 무방할 것입니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/41.gif?raw=true)
#
# 이제 실제 값을 넣어서 계산해봅시다. 만약 $dx$가 $0.01$이라고 하고, $3$부터 $3.001$까지의 넓이를 구한다고 생각합니다.
# <br><br>
#
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/42.gif?raw=true)
#
# 우리가 처음에 $A(x)$를 정의할 때, $A(x)$를 $0$부터 $x$까지의 넓이로 정의하였습니다. 때문에, $3$부터 $3.001$까지의 넓이를 계산하려면 $A(3.001) - A(3)$이 될 것입니다. 왜냐하면 $0 \sim 3.001$까지의 넓이에서 $0 \sim 3.000$까지의 넓이를 빼야 저 부분의 넓이가 되기 때문이죠. 따라서 $dA = A(3.001) - A(3)$입니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/43.gif?raw=true)
#
# 따라서 $\frac{dA}{dx} = \frac{A(3.001) - A(3)}{0.001} \approx x^2$이 됩니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/44.gif?raw=true)
#
# 이러한 성질은 비단 $x^2$에만 적용되는 것이 아닙니다. 다른 함수들도 대부분은 이러한 성질이 적용됩니다. 밑변 $dx$와 높이 $f(x)$를 곱하면 $dx$부분의 사각형 넓이가 되고, 양변을 밑변 $dx$로 나누면 $\frac{dA}{dx} \approx f(x)$라는 결론에 도달합니다. 물론 $dx$가 작으면 적을 수록 점점 값이 정확해집니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/45.gif?raw=true)
#
# 그래서 이게 무엇을 뜻할까요? 여러분은 이 개념을 통해 미적분의 위대한 아이디어 중 하나인 '도함수'에 대해 알게 되었습니다. 도함수의 개념은 사실 **넓이를 밑변으로 나누면 높이**가 된다는 아주 간단한 아이디어에서 출발했습니다. 그런데 흔히들 도함수는 **기울기** 혹은 **순간의 변화량**이라고 알고 있습니다. 그런데 도대체 순간의 변화량이 뭘까요?

# %% [markdown]
# <br>
#
# ### 3. 도함수 : 순간의 변화량? 기울기?
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/46.gif?raw=true)
#
# 정지한 사진에 자동차가 하나 있습니다. 이 자동차는 빠른가요? 느린가요? **순간**이라는 것은 정지한 단 한 시점을 의미합니다. 그런데 **변화량**이 생기려면 시간이 흘러서 변화해야합니다. 모순적이지 않나요?
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/47.gif?raw=true)
#
# 따라서 속력이라는 것을 계산하려면 특정 시점동안 시간이 흘러야만 합니다. 보통 우리는 속력을 $v = \frac{s}{t}$라고 표현합니다. 즉, 속력은 시간동안 움직인 거리를 뜻합니다. 같은 시간동안 많이 움직였으면 속력이 빠른 것이죠.
# <br><br>
