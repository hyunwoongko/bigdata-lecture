# %% [markdown]
# # 01. 확률과 통계 기초 (1)
# > 머신러닝에 반드시 필요한 확률과 통계의 기초 이론을 배웁니다.
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [Day 2]
# - permalink: /probability_statics
# - exec: colab

# %% [markdown]
# 우리는 이전 시간에 선형대수학과 그것들을 코드 상에서 어떻게 다루는지에 대해 배웠습니다. 이전에도 말씀드렸지만 선형대수학은 머신러닝의 What(무엇을?)에 해당합니다. 즉, 우리는 머신러닝에서 선형대수의 Tensor를 다룹니다.
# <br><br>
#
# 그러면 이 선형대수에서 배운 텐서조각들을 어떻게 활용해야 유의미한 결과를 도출할 수 있을까요? 여기에서 우리는 확률과 통계이론을 배웁니다. 텐서조각들로 확률 계산을 수행해 유의미한 결과를 도출할 것이기 때문입니다. 즉, 확률과 통계는 머신러닝의 How(어떻게?)에 해당합니다.

# %% [markdown]
# <br>
#
# ### 1. Fundamental of Probability
# 가장 먼저 확률에 대해 공부하기 전에 확률론의 대상이 되는 시행, 집합, 사건 등의 말에 대한 정의를 알아봅시다. 가장 먼저 우리가 주사위를 한 번 던진다고 해봅시다. 그러면 주사위의 6개의 눈 중 한 가지의 눈이 나올 것입니다. 이 때, 이렇게 **주사위를 던지는 행위를 우리는 '시행(Trial)'이라고 합니다.** 시행은 동일한 조건에서 반복해서 수행 가능해야하며, 결과가 우연에 의해 지배되어야합니다. 즉, 마음대로 결과를 조작할 수 없어야합니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/01.jpg?raw=true)
#
# 여러분이 주사위를 한 번 던지면, 1이 나올 수도, 2가 나올 수도, 3이 나올 수도 있습니다. 그러나 주사위를 한 번 던졌기 때문에, 한가지 숫자만 나오고, 2와 3이 동시에 나오는 경우는 없겠죠?
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/02.jpg?raw=true)
#
# 이 때, **나올 수 있는 모든 경우를 가리켜서 '표본공간(Sample Space)'라고 합니다.** 즉, 표본 공간이란 가능한 모든 결과들의 집합이라고 할 수 있습니다. 보통 표본공간은 S라고 씁니다. 앞으로 아래부터 어떤 개념을 S라는 이름으로 부르면 특별한 일이 없으면 표본공간을 뜻합니다.
# <br><br>
#
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/03.jpg?raw=true)
#
# 그리고 이 때, **발생 가능한 각각의 눈을 '원소(Element) 혹은 표본(Sample)'이라고 합니다.** 위 처럼 2도 원소이고 3도 원소이고 6도 원소입니다.
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/04.jpg?raw=true)
#
# 자, 이제 여기에서 눈이 3보다 작은 경우만 생각해봅시다. 언제 눈이 3보다 작을까요?
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/05.jpg?raw=true)
#
# 네. 바로 녹색 동그라미의 경우들. {1}이거나 {2}일 때입니다. 그럼 이러한 '경우'를 지칭하는 말이 있었으면 좋겠는데요.
# <br><br>
#
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/06.jpg?raw=true)
#
# 이렇게 **전체 표본공간 중, 특수한 '경우'를 나타내는 것을 '사건(Event)'라고 합니다.** '사건'은 확률의 기본 요소(선형대수의 '벡터'처럼)이면서, 앞서 이야기한 **표본 공간의 '부분집합'** 입니다. 즉, 우리는 이 사건들을 가지고 확률에 대해 생각해 볼 것입니다.
# <br><br>
#
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/08.jpg?raw=true)
#
# 또 다른 예를 하나 들어볼까요? 김철수라는 사람이 중국집에 갔다고 생각해봅시다. 중국집에는 메뉴가 짜장면, 짬뽕, 탕수육이라는 3개의 메뉴가 있고 각 메뉴는 최대 1번씩만 시키는 것이 가능하다고 가정한다면, 이 때 표본공간은 {}, {짜장면}, {짬뽕}, {탕수육}, {짜장면, 짬뽕}, {짜장면, 탕수육}, {짬뽕, 탕수육}, {짜장면, 짬뽕, 탕수육}이며, 위 8가지 경우는 '원소'에 해당합니다.
# <br><br>
#
# 이 때, 김철수씨가 메뉴를 주문한다고 생각해봅시다. 이 때, '짜장면만 시킬 경우'가 사건 A이고, '짜장면을 시킬 경우'가 사건 B, 마지막으로 '모든 메뉴를 전부 주문하는 경우'를 C라고 합시다. 그렇다면 사건 A는 {짜장면}이 되고, 사건 B는 {짜장면}, {짜장면, 탕수육}, {짬뽕, 짜장면}, {짜장면, 짬뽕, 탕수육}중 한 가지가 되겠죠? 그리고 사건 C는 {짜장면, 탕수육, 짬뽕}이 됩니다. 이해가 좀 가시나요? 그런데 아까부터 표본공간과 사건을 이야기할 때 제가 '집합'에 대해 언급했습니다. 집합이란 무엇일까요?

# %% [markdown]
# <br><br>
#
# ### 2. 집합이란?
#
# ![](https://lh3.googleusercontent.com/proxy/hZoA8ICJ__KfZNGh_ZcxtUOdhk5R3GNehZhWKwTNLHHijTn2JFYv33o41fKp79ItIo5bpp9qJ3zSAjmY8ifDXEoLQ229EodbTylX-L4J_skz8RFo8ZImuNunmYacT-9eELCcJ7L-o5DabYsZANKmg5lebFHzodY)
#
# 먼저 확률을 공부하기 전에 집합에 대해서 알아야합니다. 집합이란 어떠한 자료가 **순서 없이, 중복 없이** 저장된 자료구조를 말합니다. 이 것은 리스트나 numpy 벡터와 상당히 다른 특징인데요. 파이썬에서도 set()으로 집합을 생성할 수 있습니다. 코드의 실행 결과를 보면서 리스트(벡터)와 집합의 차이를 알아 볼까요?

# %%
# 집합과 리스트 생성
set_a = set()
list_a = list()

print('set : ', set_a)
print('list : ', list_a)
# Out:
# set :  set()
# list :  []

# %%
# 집합과 리스트에 3을 추가
set_a.add(3)
list_a.append(3)

print('set : ', set_a)
print('list : ', list_a)
# Out:
# set :  {3}
# list :  [3]

# %%
# 집합과 리스트에 3을 추가
set_a.add(3)
list_a.append(3)

print('set : ', set_a) # 중복이 없기 때문에 저장되지 않음
print('list : ', list_a) # 중복이 허용되기 때문에 저장됨
# Out:
# set :  {3}
# list :  [3, 3]

# %%
# 집합과 리스트에 한번 더 3을 추가
set_a.add(3)
list_a.append(3)

print('set : ', set_a) # 중복이 없기 때문에 저장되지 않음
print('list : ', list_a) # 중복이 허용되기 때문에 저장됨
# Out:
# set :  {3}
# list :  [3, 3, 3]

# %%
# 집합과 리스트에 1을 추가
set_a.add(1)
list_a.append(1)

print('set : ', set_a) # 순서가 없기 때문에 아무렇게 저장
print('list : ', list_a) # 순서가 있기 때문에 들어온 순서대로 차곡차곡 저장
# Out:
# set :  {1, 3}
# list :  [3, 3, 3, 1]

# %%
# 집합과 리스트에 0을 추가
set_a.add(0)
list_a.append(0)

print('set : ', set_a) # 순서가 없기 때문에 아무렇게 저장
print('list : ', list_a) # 순서가 있기 때문에 들어온 순서대로 차곡차곡 저장
# Out:
# set :  {0, 1, 3}
# list :  [3, 3, 3, 1, 0]

# %% [markdown]
# <br>
#
# 이제 집합에 **중복과 순서**가 없다는 말이 무슨 말인지 아시겠죠?
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/09.jpg?raw=true)
#
# 우리는 확률에서 **'사건'** 을 기본 요소로 다룹니다. 그리고 표본공간 중에서 그 **'사건'** 이 발생할 **'확률'** 을 계산하게 될 것입니다. 여기에서 반드시 기억하셔야할 내용은 **'표본 공간'** 은 발생할 수 있는 모든 원소의 **집합** (중복과 순서가 없음)이며, **사건은 표본공간의 부분 집합(Subset)** 입니다.

# %% [markdown]
# <br>
#
# ### 3. 집합의 연산과 표기법
# 집합에는 몇가지 연산이 있습니다. 바로 '합집합', '교집합', '차집합', '여집합' 등이 있는데요. 집합과 집합 사이에서 아래와 같은 연산을 하면 결과 집합이 반환합니다. 아래에서 알아봅시다. (중학교 1학년 때 배우는건데, 이 정도 내용은 다들 아실 것이라고 가정하고 가볍게 서머리만 하고 넘어가도 괜찮겠죠? 잘 모르시겠으면 질문하세요!)
#
# <br>
#
# #### 3.1. 교집합 (곱사건)
#
# ![](https://t1.daumcdn.net/cfile/tistory/145A8333502E0B4C0A)
#
# 교집합은 두 집합의 곱을 의미합니다. 두 집합 A, B 모두에 해당되는 집합을 바로 교집합이라고 합니다. 사건에서는 3의 배수 **'이면서'** 2의 배수인 사건 = {6, 12, 18, ...} 등을 나타낼 때 쓰입니다.
# <br><br>
#
#
# #### 3.2. 합집합 (합사건)
#
# ![](https://t1.daumcdn.net/cfile/blog/20654B45511EF8CD23)
#
# 합집합은 두 집합의 합을 의미합니다. 두 집합에서 발생 할 수 있는 모든 경우를 말합니다. 그러나, 그냥 집합 두개를 더하면 교집합 부분이 겹쳐서 더해지므로 $A + B - (A \cap B)$처럼 계산합니다. 사건에서는 3의 배수 **'또는'** 2의 배수인 사건 = {2, 3, 4, 6, 8, 9, 12, ...}등을 나타낼 때 쓰입니다.
# <br><br>
#
# #### 3.3. 차집합 (차사건)
#
# ![](https://t1.daumcdn.net/cfile/tistory/15130245502E083F28)
#
# 차집합은 두 집합의 차를 의미합니다. 집합A 에서 집합B와의 교집합부분을 제외한 순수한 집합 A만을 의미합니다. 3의 배수 **'이지만'** 2의 배수는 아닌 사건 = {3, 9, 15, 21, ...}등을 나타낼 때 쓰입니다.
# <br><br>
#
# #### 3.4. 여집합 (여사건)
#
# ![](https://t1.daumcdn.net/cfile/tistory/1319C245502E083F1F)
#
# 여집합은 해당 집합을 제외한 나머지 전부를 의미합니다. $A^C$와 같이 표기합니다. $S - A$처럼 계산하고, 3의 배수가 **'아닌'** 사건 = {1, 2, 4, 5, 7, 8, 10, 11, ...}등을 나타낼 때 쓰입니다.
# <br><br>
#
# #### 3.5. 집합의 표기법
# - 원소 나열법 : {1, 2, 3, 5}와 같이 원소를 나열합니다.
# - 조건 제시법 : {x | x > 2}와 같이 조건을 제시합니다.
#
# 앞으로 위의 두가지 방법으로 사건(집합)을 표기하려고 합니다.

# %% [markdown]
# <br>
#
# ### 3. 근원 사건
#
# 근원사건에 대해 이야기해볼까 합니다. 근원사건은 사건의 원소가 딱 1개일 때를 말합니다. 아래의 예시를 볼까요?
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/08.jpg?raw=true)
#
# - 사건 A = {x | x는 짜장면만 시키는 경우}는 {짜장면}이외에는 어떤 경우도 존재하지 않습니다. 때문에 이러한 사건은 **근원사건 입니다.** (원소가 2번 한가지)
# - 사건 B = {x | x는 짜장면을 포함해서 주문할 경우}는 다른 메뉴도 주문할 수 있다는 것이기 때문에 {짜장면}, {짜장면, 짬뽕}, {짜장면, 탕수육}, {짜장면, 짬뽕, 탕수육} 등이 존재합니다. 마지막으로 따라서 이런 사건은 **근원사건이 아닙니다.** (원소가 2, 5, 6, 8으로 여러가지)
# - 사건 C = {x | x는 모든 메뉴를 주문하는 경우}인데 {짜장면, 짬뽕, 탕수육}을 시키는 경우 말고는 존재하지 않으니 이 경우도 **근원사건입니다.** (원소가 8번 1개)
#
# <br>
#
# 근원사건은 확률을 정의할 때 나오는 중요한 개념이니 잘 알아두시길 바랍니다.

# %% [markdown]
# <br>
#
# ### 4. 배반 사건
#
# 이번엔 배반사건에 대해 알아봅니다. 배반사건은 교집합이 존재하지 않는 사건들을 말합니다. 아래의 예시를 볼까요?
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/10.jpg?raw=true)
#
# 사건 A = {x | x는 짜장면'만' 시키는 경우}이고 사건 B = {x | x는 짬뽕 '만' 시키는 경우}입니다. 두 사건 사이에 어떠한 공유원소도 없기 때문에 이러한 경우를 배반사건이라고 합니다. 배반사건 역시 굉장히 중요한 개념이니 잘 익혀두시길 바랍니다.

# %% [markdown]
# <br>
#
# ### 5. 확률
#
# 자 이제 우리가 확률을 공부하기 위한 선행조건을 모두 끝냈습니다. 이제 확률에 대해 이야기해봅시다. 확률은 여러가지의 정의가 있습니다. 가장 먼저 수학적 확률, 그리고 기하학적 확률, 마지막으로 공리적 확률에 대해 알아봅시다.
# <br><br>
#
# #### 5.1. 수학적/고전적 확률 (라플라스 확률)
# 확률의 역사에서 가장 처음 등장한 확률의 개념은 바로 라플라스의 수학적 확률입니다. 수학적 확률에서 주의할 것은 반드시 **'근원 사건이 일어날 가능성이 모두 같을 때'** 만 수학적 확률을 적용할 수 있다는 조건이 있습니다. 예를 들면, 우리가 주사위를 한번 던진다고 할 때, 근원사건은 {1}, {2}, {3}, ... , {6}로 총 6가지가 있습니다.
# <br><br>
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Fair_dice_probability_distribution.svg/1200px-Fair_dice_probability_distribution.svg.png)
#
# 우리는 흔히 이 여섯개의 근원사건이 발생할 확률은 $\frac{1}{6}$로 모두 똑같다고 합니다. 이들이 일어날 확률이 같다는 것은 모든 근원사건이 일어날 가능성이 같다는 것으로 이해할 수 있습니다. 이렇게 모든 근원 사건이 일어날 확률이 같을 때는 우리가 "수학적 확률을 계산한다"라고 말 할수 있습니다.
# <br><br>
#
# 우리가 이 때, 수학적 확률을 계산할 때는 아래와 같은 방법으로 계산합니다.
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/11.jpg?raw=true)
#
# 확률은 영어로 Probability이기 때문에 확률을 나타내는 함수를 우리는 $P$라고 부릅니다. 수학적 확률에서는 표본공간S의 부분집합인 사건 A가 일어날 확률을 $P(A) = \frac{n(A)}{n(S)}$로 정의 합니다. 즉, 표본공간이 {1}, {2}, {3}, ... , {6}로 총 6가지이고, 그 중에서 한가지 사건이 일어날 확률이므로 $\frac{1}{6}$이 됩니다. 여기에서 우리는 중요한 성질을 알 수 있는데, 근원사건의 전체 갯수에서 한가지가 일어날 확률이기 때문에, 사건A 는 근원사건의 전체를 넘을 수 없습니다. 따라서 확률 $P(A)$는 0 ~ 1의 범위를 가지게 됩니다.
# <br><br>
#
# 꽤나 깔끔한 개념으로 보이나, 수학적 확률은 곧바로 많은 문제에 직면했습니다. 만약 원소의 수를 셀 수 없는 경우나 근원사건이 일어날 확률이 다른 경우에는 어떻게 할까요? 예를 들어 아래와 같이 우리가 양궁을 한다고 해봅시다.
# <br><br>
#
# ![](https://data.ac-illust.com/data/thumbnails/0f/0f30392fce08598d9746b81440a9f87a_t.jpeg)
#
# 화살은 과녁의 어디든 꽂힐 수 있습니다. 중앙으로부터 0.5cm부근에도, 0.49cm부근에도, 0.499cm부근에도 화살이 꽂힐 수 있습니다. 그러면 우리가 화살을 쐈을 때, 노란색 영역에 꽂힐 확률은 얼마나 될까요? 정답은 화살이 꽂힐 수 있는 위치는 연속적인 개념이기 때문에 수학적/고전적 확률로는 원소의 수를 세는 것 자체가 불가능합니다. (무한개의 꽂힐 수 있는 공간이 있기 때문에)
# <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/15.jpg?raw=true)
#
# 또 우리가 윷놀이를 한다고 해봅시다. 이 때, 도, 개, 걸, 윷, 모가 나올 확률이 각각 다릅니다. 실제로 도나 개가 나올 확률이 가장 높으며 윷이나 모가 나올 확률이 가장 낮습니다. 그런데 이런 경우 각 근원사건이 일어날 확률이 다른데, 단순히 원소 갯수만 세서 비교하면 '도가 등장할 확률'은 $\frac{도}{도, 개, 걸, 윷, 모}$ = $\frac{1}{5}$이고 '윷이 등장할 확률'은 $\frac{도}{도, 개, 걸, 윷, 모}$ = $\frac{1}{5}$처럼 둘이 같아집니다. 따라서 이런 경우에 라플라스의 확률 개념을 적용하는 것은 옳지 못합니다. 이러한 문제를 해결하기 위해 시간이 흐르면서 기하학적 확률, 통계적 확률, 대수의 법칙 등의 개념이 등장해서 몇몇 문제가 해결되었지만 최종적으로 끝판왕인 콜모고로프의 공리적 확률이라는 개념이 등장해서 확률을 대부분의 문제에 쉽게 적용이 가능해졌습니다. 따라서 모두 생략하고 바로 공리적 확률에 대해 배워봅시다.

# %% [markdown]
# <br>
#
# #### 5.2. 공리적 확률 (콜모고로프 확률)
#
# 고전적 확률은 근원사건이 일어날 확률이 같을때만 사용가능 했지만 근원사건이 일어날 확률이 다르거나, 원소의 수를 세는 것이 어려운 경우에 많은 한계에 부딪혔습니다. 때문에 보다 더 다양한 경우에 확률을 적용하기 위해서 아래와 같은 세가지 공리를 제안했습니다.
# <br><br>
#
# 1. 확률은 0보다 같거나 크다. ($P(A) \geq 0$)
# 2. 확률의 최대 값은 1이다. ($P(S) = 1$)
# 3. (쌍마다) 배반사건에 대해 합사건의 확률은 확률의 합과 같다.
# <br><br>
#
#
# 가장 먼저 확률은 0보다 크거나 같아야합니다. 음수의 확률은 존재할 수 없습니다. 그리고 확률의 최대값은 1이여야 합니다. 표본공간 S에 있는 모든 사건이 발생할수 있는 확률의 합이 1이라는 것입니다. 그리고 배반사건의 합사건의 확률이 확률의 합과 같다는 것은 말이 조금 어려운데요 아래에서 조금 더 자세히 볼까요? <br><br>
#
# ![img](https://github.com/gusdnd852/bigdata-lecture/blob/master/_notebooks/img/Day2/16.jpg?raw=true)
#
# 위의 벤다이어그램을 보면 이 개념을 쉽게 이해할 수 있습니다. 제가 위에서 **'배반 사건'은 서로 교집합이 없는 사건들** 이라고 말했습니다. 위의 경우 사건들끼리 교집합을 가진 사건이 하나도 없기 때문에 이들은 모두 쌍마다 배반사건이라고 부릅니다. (그냥 배반사건으로 이해해도 무방합니다.)
# <br><br>
#
# 확률의 합과 합사건의 확률이 같다는 것은 $P(A + B + C) = P(A) + P(B) + P(C)$라는 것입니다. $Z = A + B + C$라고 한다면 $Z$ = {1, 2, 3, 4, 5, 6, 7}이므로 전체 10개의 원소중에 Z가 일어날 확률 $P(Z)$는 0.7가 됩니다. 그리고 $P(A)$는 10개중 3개가 일어날 확률로 0.3, $P(B)$도 0.3, P(C)는 1개의 원소만 있으므로 0.1이 되고 이들의 합인 $P(A) + P(B) + P(C)$도 역시 0.3 + 0.3 + 0.1 = 0.7이 됩니다. 간단하죠? 이 3가지 조건만 만족하면 그 어떠한 경우라도, 이게 넓이던 부피던 길이던간에 상관없이 이제부터는 확률이라고 칭할 수 있다는 것입니다. <br><br>
#
# 이 공리적 확률이 나온 다음부터 확률의 개념이 크게 넓어졌고 산업 여기저기에 쓰일 수 있게 되었습니다. 공리적 확률이라는 개념이 약간 뜬구름 잡는 느낌일 수도 있는데요. **공리적 확률의 진짜 의의는 확률이라는건 0 ~ 1사이의 값이여야하고, 넓이던 부피던 길이던 뭐든지 이제부터 확률로서 칭할 수 있다.** 로 이해하시고 넘어가면 됩니다. 굳이 뭐 외우시고 할게 아니라 굵은글씨만 받아들이면 됩니다. 그러니까 양궁 과녁에 노란색 부분에 화살이 맞을 확률을 계산할때 원소의 갯수는 못 세지만 $\frac{노란색 넓이}{전체 과녁넓이}$ 처럼 계산할 수 있다는 것입니다. 노란색 부분이랑 다른 부분들이랑 겹치는 부분이 없는 배반사건이니까요. (사실 정말 엄격하게 공리적 확률의 정의를 말하려면 시그마 대수라는 개념을 설명드려야 하는데 그러려면 멱집합 이야기가 나와야하고.. 너무 깊게 가는 것 같으므로 생략하겠습니다. 관심있으신분은 검색해보시거나 저한테 질문하세요!)

# %% [markdown]
# <br>
#
# ### 6. 조건부 확률
# 이제 대망의 조건부 확률에 대해 이야기해봅시다. 이 조건부 확률은 곧바로 뒤에 베이즈 정리로 연결되고, 베이즈 정리는 거의 대부분의 지도학습 딥러닝 알고리즘의 최적화과정에 있어서 가장 중요한 축이므로 조건부 확률에 대한 확실한 이해가 정말정말 중요합니다. (별표 5개 쳐도 모자랍니다.)
# <br><br>
#
# ![](https://lh3.googleusercontent.com/proxy/qaOmtI2E1X7jsrDHA8QQBaR3qQRbNO9qMr5uejtOpy9qwyRJ2hEYR57O2RSGfjx2Np-joLUkMISL-huJQAqr6UEN_1PiyEN2ZK4qSZjijkjcrTtkZyv5u4kmftjXDgkswrt63AOsKmEHcb4C2E-OZuDjO8HZoz4FwrfVKNBp7vqSEruxyudbycnjzdvHUFbsdMsn3Q)
#
# 조건부 확률은 $P(A)$가 아니라 $P(A | B)$처럼 씁니다. 이러한 표기법은 사건 B가 일어났을 때, 사건 A가 일어난 것이라고 이해하시면 됩니다. 계산은 우선 B라는 사건이 일어났으니 분모에 $P(B)$를 써주고, 그 중에서 A가 일어난 사건이니 분자에 $P(A \cap B)$를 써줍니다. 따라서 조건부확률 $P(A | B) = \frac{P(A \cap B)}{P(B)}$처럼 계산합니다.
# <br><br>
#
# 이걸 우리가 배우는 데이터 사이언스에 연결시키면, (분모)사진 1장을 골랐는데 (분자)그 사진이 고양이 사진일 확률이 되는거고, (분모)안경쓴 사람 한명을 뽑았는데, (분자)그 사람이 하루에 6시간 이상 컴퓨터를 할 확률이 됩니다. 거의 대부분의 문제에 대응되는 개념인 만큼 정말 중요합니다. 근데 사실 처음에 이 조건부 확률이라는 개념을 접하면 굉장히 뜬구름 잡는 느낌입니다. 저걸 왜 저렇게 계산하지? 왜 교집합이여야 하지? 등등.. 자 이제부터 정말 쉬운 예제를 본셔 과연 진정으로 조건부확률이 의미하는 바가 뭔지 배워봅시다.
# <br><br>
